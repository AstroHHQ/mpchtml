# %% [markdown]
# ## 获取MPC上小行星的html
# 作者：AstroHHQ

# %% [markdown]
# load import & minorplanet list

# %%
#load import
import numpy as np
import pandas as pd
from urllib.request import urlopen
from requests.api import request

mpcdata = pd.read_table('mpc.txt')
#mpcdata.sort_values('Diam',ascending=False)
sort_data = mpcdata.sort_values('Diam',ascending=False)
#mpcdata['Name'][0]
mp_name = mpcdata.loc[:,['Name','Diam']]
mp_name.insert(2,'type','?')
mp_name['PHA'] = -1# -1:dont know  0: no  1:is potentially hazadous asteriod!
mp_name
# Out:
# /usr/lib/python3/dist-packages/requests/__init__.py:89: RequestsDependencyWarning: urllib3 (1.26.8) or chardet (3.0.4) doesn't match a supported version!
#   warnings.warn("urllib3 ({}) or chardet ({}) doesn't match a supported "
#             Name   Diam type  PHA
# 0        1991 VA  0.017    ?   -1
# 1       1994 CJ1  0.156    ?   -1
# 2        1995 CR  0.130    ?   -1
# 3        1995 HM  0.094    ?   -1
# 4        1996 GQ  0.071    ?   -1
# ...          ...    ...  ...  ...
# 1310   2011 LT17  0.134    ?   -1
# 1311   2014 AY28  0.122    ?   -1
# 1312  2014 QX266  0.091    ?   -1
# 1313  2015 BY310  0.130    ?   -1
# 1314     2012 NP  0.160    ?   -1
#
# [1315 rows x 4 columns]

# %% [markdown]
# creat a new list of minorplanet(record it`s type and if pha)
#
# no.16,1206-1246,1282 无法读取

# %%
df  = mp_name
df['search?'] = True
df['search?'][16,1282]  = False
df['search?'][1209:1246]  = False
df[1200:1250]
# Out:
# /tmp/ipykernel_2662401/2666359979.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['search?'][16,1282]  = False
# /home/astrohhq/.local/lib/python3.8/site-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# /tmp/ipykernel_2662401/2666359979.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['search?'][1209:1246]  = False
#                            Name   Diam type  PHA  search?
# 1200                  2021 GQ10  0.014    ?   -1     True
# 1201                   2021 HC3  0.143    ?   -1     True
# 1202                    2021 HN  0.012    ?   -1     True
# 1203                   2021 JB6  0.005    ?   -1     True
# 1204                   2021 JR3  0.030    ?   -1     True
# 1205                   2021 KN2  0.006    ?   -1     True
# 1206                   2021 NY1  0.119    ?   -1     True
# 1207                    2021 RS  0.027    ?   -1     True
# 1208                   2021 UH2  0.026    ?   -1     True
# 1209                333P/LINEAR    NaN    ?   -1    False
# 1210       47P/Ashbrook-Jackson    NaN    ?   -1    False
# 1211           49P/Arend-Rigaux    NaN    ?   -1    False
# 1212  67P/Churyumov-Gerasimenko    NaN    ?   -1    False
# 1213                  93P/Lovas    NaN    ?   -1    False
# 1214              94P/Russell 4    NaN    ?   -1    False
# 1215     C/2017 T2  (PanSTARRS)    NaN    ?   -1    False
# 1216                     Derm0f  0.135    ?   -1    False
# 1217                     Derm1a  0.079    ?   -1    False
# 1218                     Derm1c  0.133    ?   -1    False
# 1219                     Derm2g  0.155    ?   -1    False
# 1220                     Derm3h  0.094    ?   -1    False
# 1221                     Derm3k  0.107    ?   -1    False
# 1222                     Derm4c  0.103    ?   -1    False
# 1223                     Derm5f  0.130    ?   -1    False
# 1224                     Derm5i  0.149    ?   -1    False
# 1225                     Derm6c  0.147    ?   -1    False
# 1226                     Derm6e  0.094    ?   -1    False
# 1227                     Derm6f  0.103    ?   -1    False
# 1228                     Derm6k  0.117    ?   -1    False
# 1229                     Derm7d  0.118    ?   -1    False
# 1230                     Derm7e  0.110    ?   -1    False
# 1231                     Derm7o  0.148    ?   -1    False
# 1232                     Derm8e  0.094    ?   -1    False
# 1233                P/2006 HR30    NaN    ?   -1    False
# 1234                P/2016 BA14    NaN    ?   -1    False
# 1235                     P000DV    NaN    ?   -1    False
# 1236                     P000K7    NaN    ?   -1    False
# 1237                     P000TQ    NaN    ?   -1    False
# 1238                     P000ZE    NaN    ?   -1    False
# 1239                     P0012V    NaN    ?   -1    False
# 1240                     P001GV    NaN    ?   -1    False
# 1241                     P002I1    NaN    ?   -1    False
# 1242                     P002I6    NaN    ?   -1    False
# 1243                     P002RZ    NaN    ?   -1    False
# 1244                       YORP  0.086    ?   -1    False
# 1245                    Mjolnir  0.142    ?   -1    False
# 1246                   2003 MA3  0.136    ?   -1     True
# 1247                  2000 EH26  0.136    ?   -1     True
# 1248                  1996 XB27  0.136    ?   -1     True
# 1249                    2006 UP  0.075    ?   -1     True

# %% [markdown]
# ### re匹配
# .* 贪婪
# .* ? 惰性

# %%
import requests as rq
from tqdm import tqdm
import time
import re

# %% [markdown]
# 测试单个search

# %%
name = df['Name'][6]
name = name.replace(' ','+')
print('hi')
name
# Out:
# hi
# '1997+UR'

# %%
#get url from mpc
url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
head ={
    'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
}
s = rq.session()
s.keep_alive = False
s.proxies = {'https':'183.220.195.163:80'}
#s.headers = head
resp = s.get(url)
with open(name+'.html',mode='w') as f:
    f.write(resp.text)

# %% [markdown]
# ## 批量保存html

# %%
# Out:
#   1%|          | 10/1315 [02:31<5:30:02, 15.17s/it]
# ---------------------------------------------------------------------------
# TimeoutError                              Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      94     if err is not None:
# ---> 95         raise err
#      96
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#
# TimeoutError: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     699             if is_new_proxy_conn and http_tunnel_required:
# --> 700                 self._prepare_proxy(conn)
#     701
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     993
# --> 994         conn.connect()
#     995
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     185         except SocketError as e:
# --> 186             raise NewConnectionError(
#     187                 self, "Failed to establish a new connection: %s" % e
#
# NewConnectionError: <urllib3.connection.HTTPSConnection object at 0x7f38506c0790>: Failed to establish a new connection: [Errno 110] Connection timed out
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784
# --> 785             retries = retries.increment(
#     786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='minorplanetcenter.net', port=443): Max retries exceeded with url: /db_search/show_object?utf8=%E2%9C%93&object_id=1999+FN19 (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f38506c0790>: Failed to establish a new connection: [Errno 110] Connection timed out')))
#
# During handling of the above exception, another exception occurred:
#
# ProxyError                                Traceback (most recent call last)
# /tmp/ipykernel_2659688/847531481.py in <module>
#      16       s.proxies = {'https':'183.220.195.163:80'}
#      17       #s.headers = head
# ---> 18       resp = s.get(url)
#      19       with open(name+'.html',mode='w') as f:
#      20          f.write(resp.text)
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     508
#     509             if isinstance(e.reason, _ProxyError):
# --> 510                 raise ProxyError(e, request=request)
#     511
#     512             if isinstance(e.reason, _SSLError):
#
# ProxyError: HTTPSConnectionPool(host='minorplanetcenter.net', port=443): Max retries exceeded with url: /db_search/show_object?utf8=%E2%9C%93&object_id=1999+FN19 (Caused by ProxyError('Cannot connect to proxy.', NewConnectionError('<urllib3.connection.HTTPSConnection object at 0x7f38506c0790>: Failed to establish a new connection: [Errno 110] Connection timed out')))

# %%
#space to "+"
#name = mp_name[5]
#name = name.replace(' ','+')
lenMp = len(df)
for i in tqdm(range(10,lenMp)):
   if df['search?'][i]:  
      name = df['Name'][i]
      name = name.replace(' ','+')
      #get url from mpc
      url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
      head ={
         'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
      }
      s = rq.session()
      s.keep_alive = False
      s.proxies = {'https':'183.172.105.47:7890','https':'123.56.141.45:22','https':'1.14.122.251:1080'}
      #s.headers = head
      resp = s.get(url)
      with open(name+'.html',mode='w') as f:
         f.write(resp.text)
# Out:
#   7%|██▋                                    | 91/1305 [19:15<4:16:49, 12.69s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2662401/194301829.py in <module>
#      16       s.proxies = {'https':'183.172.105.47:7890','https':'123.56.141.45:22','https':'1.14.122.251:1080'}
#      17       #s.headers = head
# ---> 18       resp = s.get(url)
#      19       with open(name+'.html',mode='w') as f:
#      20          f.write(resp.text)
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# /usr/lib/python3/dist-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# /usr/lib/python3/dist-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/.local/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/.local/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     765                 if self.chunk_left == 0:
#     766                     break
# --> 767                 chunk = self._handle_chunk(amt)
#     768                 decoded = self._decode(
#     769                     chunk, decode_content=decode_content, flush_decoder=False
#
# ~/.local/lib/python3.8/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     718             returned_chunk = value
#     719         else:  # amt > self.chunk_left
# --> 720             returned_chunk = self._fp._safe_read(self.chunk_left)
#     721             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     722             self.chunk_left = None
#
# /usr/lib/python3.8/http/client.py in _safe_read(self, amt)
#     611         IncompleteRead exception can be used to detect the problem.
#     612         """
# --> 613         data = self.fp.read(amt)
#     614         if len(data) < amt:
#     615             raise IncompleteRead(data, amt-len(data))
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/.local/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     317     def recv_into(self, *args, **kwargs):
#     318         try:
# --> 319             return self.connection.recv_into(*args, **kwargs)
#     320         except OpenSSL.SSL.SysCallError as e:
#     321             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~/.local/lib/python3.8/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1894             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1895         else:
# -> 1896             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1897         self._raise_ssl_error(self._ssl, result)
#    1898
#
# KeyboardInterrupt:

# %%
#space to "+"
#name = mp_name[5]
#name = name.replace(' ','+')
lenMp = len(df)
for i in tqdm(range(100,lenMp)):
   if df['search?'][i]:  
      name = df['Name'][i]
      name = name.replace(' ','+')
      #get url from mpc
      url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
      head ={
         'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
      }
      s = rq.session()
      s.keep_alive = False
      s.proxies = {'https':'183.172.105.47:7890','https':'123.56.141.45:22','https':'1.14.122.251:1080'}
      #s.headers = head
      resp = s.get(url)
      with open(name+'.html',mode='w') as f:
         f.write(resp.text)
# Out:
#  16%|██████                                | 194/1215 [19:51<1:44:31,  6.14s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2662401/3773362656.py in <module>
#      16       s.proxies = {'https':'183.172.105.47:7890','https':'123.56.141.45:22','https':'1.14.122.251:1080'}
#      17       #s.headers = head
# ---> 18       resp = s.get(url)
#      19       with open(name+'.html',mode='w') as f:
#      20          f.write(resp.text)
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     684
#     685         if not stream:
# --> 686             r.content
#     687
#     688         return r
#
# /usr/lib/python3/dist-packages/requests/models.py in content(self)
#     826                 self._content = None
#     827             else:
# --> 828                 self._content = b''.join(self.iter_content(CONTENT_CHUNK_SIZE)) or b''
#     829
#     830         self._content_consumed = True
#
# /usr/lib/python3/dist-packages/requests/models.py in generate()
#     748             if hasattr(self.raw, 'stream'):
#     749                 try:
# --> 750                     for chunk in self.raw.stream(chunk_size, decode_content=True):
#     751                         yield chunk
#     752                 except ProtocolError as e:
#
# ~/.local/lib/python3.8/site-packages/urllib3/response.py in stream(self, amt, decode_content)
#     570         """
#     571         if self.chunked and self.supports_chunked_reads():
# --> 572             for line in self.read_chunked(amt, decode_content=decode_content):
#     573                 yield line
#     574         else:
#
# ~/.local/lib/python3.8/site-packages/urllib3/response.py in read_chunked(self, amt, decode_content)
#     765                 if self.chunk_left == 0:
#     766                     break
# --> 767                 chunk = self._handle_chunk(amt)
#     768                 decoded = self._decode(
#     769                     chunk, decode_content=decode_content, flush_decoder=False
#
# ~/.local/lib/python3.8/site-packages/urllib3/response.py in _handle_chunk(self, amt)
#     718             returned_chunk = value
#     719         else:  # amt > self.chunk_left
# --> 720             returned_chunk = self._fp._safe_read(self.chunk_left)
#     721             self._fp._safe_read(2)  # Toss the CRLF at the end of the chunk.
#     722             self.chunk_left = None
#
# /usr/lib/python3.8/http/client.py in _safe_read(self, amt)
#     611         IncompleteRead exception can be used to detect the problem.
#     612         """
# --> 613         data = self.fp.read(amt)
#     614         if len(data) < amt:
#     615             raise IncompleteRead(data, amt-len(data))
#
# /usr/lib/python3.8/socket.py in readinto(self, b)
#     667         while True:
#     668             try:
# --> 669                 return self._sock.recv_into(b)
#     670             except timeout:
#     671                 self._timeout_occurred = True
#
# ~/.local/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in recv_into(self, *args, **kwargs)
#     317     def recv_into(self, *args, **kwargs):
#     318         try:
# --> 319             return self.connection.recv_into(*args, **kwargs)
#     320         except OpenSSL.SSL.SysCallError as e:
#     321             if self.suppress_ragged_eofs and e.args == (-1, "Unexpected EOF"):
#
# ~/.local/lib/python3.8/site-packages/OpenSSL/SSL.py in recv_into(self, buffer, nbytes, flags)
#    1894             result = _lib.SSL_peek(self._ssl, buf, nbytes)
#    1895         else:
# -> 1896             result = _lib.SSL_read(self._ssl, buf, nbytes)
#    1897         self._raise_ssl_error(self._ssl, result)
#    1898
#
# KeyboardInterrupt:

# %%
#space to "+"
#name = mp_name[5]
#name = name.replace(' ','+')
lenMp = len(df)
for i in tqdm(range(294,lenMp)):
   if df['search?'][i]:  
      name = df['Name'][i]
      name = name.replace(' ','+')
      #get url from mpc
      url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
      head ={
         'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
      }
      s = rq.session()
      s.keep_alive = False
      s.proxies = {'https':'183.172.105.47:7890','https':'123.56.141.45:22','https':'1.14.122.251:1080'}
      #s.headers = head
      resp = s.get(url)
      with open(name+'.html',mode='w') as f:
         f.write(resp.text)
# Out:
#  20%|████████▏                               | 208/1021 [10:23<40:37,  3.00s/it]
# ---------------------------------------------------------------------------
# SysCallError                              Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     497             try:
# --> 498                 cnx.do_handshake()
#     499             except OpenSSL.SSL.WantReadError:
#
# ~/.local/lib/python3.8/site-packages/OpenSSL/SSL.py in do_handshake(self)
#    1990         result = _lib.SSL_do_handshake(self._ssl)
# -> 1991         self._raise_ssl_error(self._ssl, result)
#    1992
#
# ~/.local/lib/python3.8/site-packages/OpenSSL/SSL.py in _raise_ssl_error(self, ssl, result)
#    1691                     if errno != 0:
# -> 1692                         raise SysCallError(errno, errorcode.get(errno))
#    1693                 raise SysCallError(-1, "Unexpected EOF")
#
# SysCallError: (104, 'ECONNRESET')
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     699             if is_new_proxy_conn and http_tunnel_required:
# --> 700                 self._prepare_proxy(conn)
#     701
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     993
# --> 994         conn.connect()
#     995
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     415
# --> 416         self.sock = ssl_wrap_socket(
#     417             sock=conn,
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     448     if send_sni:
# --> 449         ssl_sock = _ssl_wrap_socket_impl(
#     450             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     492     if server_hostname:
# --> 493         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     494     else:
#
# ~/.local/lib/python3.8/site-packages/urllib3/contrib/pyopenssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname)
#     503             except OpenSSL.SSL.Error as e:
# --> 504                 raise ssl.SSLError("bad handshake: %r" % e)
#     505             break
#
# SSLError: ("bad handshake: SysCallError(104, 'ECONNRESET')",)
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     784
# --> 785             retries = retries.increment(
#     786                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     591         if new_retry.is_exhausted():
# --> 592             raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     593
#
# MaxRetryError: HTTPSConnectionPool(host='minorplanetcenter.net', port=443): Max retries exceeded with url: /db_search/show_object?utf8=%E2%9C%93&object_id=2014+CR (Caused by SSLError(SSLError("bad handshake: SysCallError(104, 'ECONNRESET')")))
#
# During handling of the above exception, another exception occurred:
#
# SSLError                                  Traceback (most recent call last)
# /tmp/ipykernel_2662401/2774890784.py in <module>
#      16       s.proxies = {'https':'183.172.105.47:7890','https':'123.56.141.45:22','https':'1.14.122.251:1080'}
#      17       #s.headers = head
# ---> 18       resp = s.get(url)
#      19       with open(name+'.html',mode='w') as f:
#      20          f.write(resp.text)
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     512             if isinstance(e.reason, _SSLError):
#     513                 # This branch is for urllib3 v1.22 and later.
# --> 514                 raise SSLError(e, request=request)
#     515
#     516             raise ConnectionError(e, request=request)
#
# SSLError: HTTPSConnectionPool(host='minorplanetcenter.net', port=443): Max retries exceeded with url: /db_search/show_object?utf8=%E2%9C%93&object_id=2014+CR (Caused by SSLError(SSLError("bad handshake: SysCallError(104, 'ECONNRESET')")))

# %%
#space to "+"
#name = mp_name[5]
#name = name.replace(' ','+')
lenMp = len(df)
for i in tqdm(range(502,lenMp)):
   if df['search?'][i]:  
      name = df['Name'][i]
      name = name.replace(' ','+')
      #get url from mpc
      url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
      head ={
         'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
      }
      s = rq.session()
      s.keep_alive = False
      s.proxies = {'https':'183.220.195.163:80'}
      #s.headers = head
      resp = s.get(url)
      with open(name+'.html',mode='w') as f:
         f.write(resp.text)
# Out:
#   2%|▋                                       | 14/813 [01:24<1:20:41,  6.06s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2662401/940668589.py in <module>
#      16       s.proxies = {'https':'183.220.195.163:80'}
#      17       #s.headers = head
# ---> 18       resp = s.get(url)
#      19       with open(name+'.html',mode='w') as f:
#      20          f.write(resp.text)
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             )
#     699             if is_new_proxy_conn and http_tunnel_required:
# --> 700                 self._prepare_proxy(conn)
#     701
#     702             # Make the request on the httplib connection object.
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     992             conn.tls_in_tls_required = True
#     993
# --> 994         conn.connect()
#     995
#     996     def _new_conn(self):
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     356     def connect(self):
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#     360         tls_in_tls = False
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83             if source_address:
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#      87
#
# KeyboardInterrupt:

# %%
#space to "+"
#name = mp_name[5]
#name = name.replace(' ','+')
lenMp = len(df)
for i in tqdm(range(513,lenMp)):
   if df['search?'][i]:  
      name = df['Name'][i]
      name = name.replace(' ','+')
      #get url from mpc
      url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
      head ={
         'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
      }
      s = rq.session()
      s.keep_alive = False
      s.proxies = {'https':'120.42.46.226:6666'}
      #s.headers = head
      resp = s.get(url)
      with open(name+'.html',mode='w') as f:
         f.write(resp.text)
# Out:
#  12%|█████▏                                    | 99/802 [07:19<52:00,  4.44s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /tmp/ipykernel_2662401/4273210023.py in <module>
#      16       s.proxies = {'https':'120.42.46.226:6666'}
#      17       #s.headers = head
# ---> 18       resp = s.get(url)
#      19       with open(name+'.html',mode='w') as f:
#      20          f.write(resp.text)
#
# /usr/lib/python3/dist-packages/requests/sessions.py in get(self, url, **kwargs)
#     544
#     545         kwargs.setdefault('allow_redirects', True)
# --> 546         return self.request('GET', url, **kwargs)
#     547
#     548     def options(self, url, **kwargs):
#
# /usr/lib/python3/dist-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     531         }
#     532         send_kwargs.update(settings)
# --> 533         resp = self.send(prep, **send_kwargs)
#     534
#     535         return resp
#
# /usr/lib/python3/dist-packages/requests/sessions.py in send(self, request, **kwargs)
#     644
#     645         # Send the request
# --> 646         r = adapter.send(request, **kwargs)
#     647
#     648         # Total elapsed time of the request (approximately)
#
# /usr/lib/python3/dist-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             )
#     699             if is_new_proxy_conn and http_tunnel_required:
# --> 700                 self._prepare_proxy(conn)
#     701
#     702             # Make the request on the httplib connection object.
#
# ~/.local/lib/python3.8/site-packages/urllib3/connectionpool.py in _prepare_proxy(self, conn)
#     992             conn.tls_in_tls_required = True
#     993
# --> 994         conn.connect()
#     995
#     996     def _new_conn(self):
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     356     def connect(self):
#     357         # Add certificate verification
# --> 358         conn = self._new_conn()
#     359         hostname = self.host
#     360         tls_in_tls = False
#
# ~/.local/lib/python3.8/site-packages/urllib3/connection.py in _new_conn(self)
#     172
#     173         try:
# --> 174             conn = connection.create_connection(
#     175                 (self._dns_host, self.port), self.timeout, **extra_kw
#     176             )
#
# ~/.local/lib/python3.8/site-packages/urllib3/util/connection.py in create_connection(address, timeout, source_address, socket_options)
#      83             if source_address:
#      84                 sock.bind(source_address)
# ---> 85             sock.connect(sa)
#      86             return sock
#      87
#
# KeyboardInterrupt:

# %%
#space to "+"
#name = mp_name[5]
#name = name.replace(' ','+')
lenMp = len(df)
for i in tqdm(range(611,lenMp)):
   if df['search?'][i]:  
      name = df['Name'][i]
      name = name.replace(' ','+')
      #get url from mpc
      url = f'https://minorplanetcenter.net/db_search/show_object?utf8=%E2%9C%93&object_id={name}'
      head ={
         'User-Agent':'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:94.0) Gecko/20100101 Firefox/94.0'
      }
      s = rq.session()
      s.keep_alive = False
      s.proxies = {'https':'47.103.18.139:7890'}
      #s.headers = head
        
      resp = s.get(url)
      with open(name+'.html',mode='w') as f:
         f.write(resp.text)
# Out:
#   0%|                                         | 1/704 [00:29<5:49:41, 29.85s/it]
